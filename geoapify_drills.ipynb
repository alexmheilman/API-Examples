# %% [markdown]
# # Geoapify Drills
#
# Create code to answer each of the following questions.
#
# > **Hint:** You will need multiple target URLs and multiple API requests.

# %%
# Dependencies
import requests
import json

# Import the API key
from config import geoapify_key

# %% [markdown]
# ## 1. What are the geocoordinates (latitude and longitude) of Brisbane, Australia?

# %%
# Set the search parameters
target_city = 'Brisbane, Austrailia'

# Build URL using the geocode endpoint
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"
target_url
# Out:
# 'https://api.geoapify.com/v1/geocode/search?text=Brisbane, Austrailia&format=json&apiKey=c242fab0818a46ff9dda30ba393bfea0'

# %%
# Run request
geo_data = requests.get(target_url).json()

# Print the json (pretty printed)
geo_data
# Out:
# {'results': [{'country_code': 'us',
#    'country': 'United States',
#    'county': 'San Mateo County',
#    'datasource': {'sourcename': 'whosonfirst',
#     'url': 'https://www.whosonfirst.org/docs/licenses/'},
#    'state': 'California',
#    'city': 'Brisbane',
#    'lon': -122.340013,
#    'lat': 37.690193,
#    'state_code': 'CA',
#    'formatted': 'Brisbane, CA, United States of America',
#    'address_line1': 'Brisbane, CA',
#    'address_line2': 'United States of America',
#    'timezone': {'name': 'America/Los_Angeles',
#     'offset_STD': '-08:00',
#     'offset_STD_seconds': -28800,
#     'offset_DST': '-07:00',
#     'offset_DST_seconds': -25200,
#     'abbreviation_STD': 'PST',
#     'abbreviation_DST': 'PDT'},
#    'result_type': 'city',
#    'rank': {'popularity': 4.135364477370414,
#     'confidence': 0.5,
#     'confidence_city_level': 0.5,
#     'match_type': 'full_match'},
#    'place_id': '51c0cde2c5c2955ec059cd76853e58d84240c00208e2031d77686f736f6e66697273743a6c6f63616c6974793a3835393232353531',
#    'bbox': {'lon1': -122.426497,
#     'lat1': 37.671258,
#     'lon2': -122.251979,
#     'lat2': 37.708431}},
#   {'country_code': 'us',
#    'name': 'Brisbane',
#    'housenumber': '98-32',
#    'street': '57th Avenue',
#    'country': 'United States',
#    'county': 'Queens County',
#    'datasource': {'sourcename': 'openstreetmap',
#     'attribution': '© OpenStreetMap contributors',
#     'license': 'Open Database License',
#     'url': 'https://www.openstreetmap.org/copyright'},
#    'postcode': '11368',
#    'state': 'New York',
#    'city': 'New York',
#    'district': 'Queens',
#    'suburb': 'Corona',
#    'lon': -73.861397,
#    'lat': 40.737026,
#    'state_code': 'NY',
#    'formatted': 'Brisbane, 98-32 57th Avenue, New York, NY 11368, United States of America',
#    'address_line1': 'Brisbane',
#    'address_line2': '98-32 57th Avenue, New York, NY 11368, United States of America',
#    'timezone': {'name': 'America/New_York',
#     'offset_STD': '-05:00',
#     'offset_STD_seconds': -18000,
#     'offset_DST': '-04:00',
#     'offset_DST_seconds': -14400,
#     'abbreviation_STD': 'EST',
#     'abbreviation_DST': 'EDT'},
#    'result_type': 'amenity',
#    'rank': {'popularity': 7.129638580267105,
#     'confidence': 0.5,
#     'match_type': 'full_match'},
#    'place_id': '51d7f7e120217752c0599e2633de565e4440f00102f9013b79ef0e00000000c002019203084272697362616e65e203216f70656e7374726565746d61703a76656e75653a7761792f323530353735313633',
#    'bbox': {'lon1': -73.8616681,
#     'lat1': 40.736666,
#     'lon2': -73.8611459,
#     'lat2': 40.7372663}},
#   {'country_code': 'au',
#    'country': 'Australia',
#    'county': 'Brisbane',
#    'datasource': {'sourcename': 'whosonfirst',
#     'url': 'https://www.whosonfirst.org/docs/licenses/'},
#    'state': 'Queensland',
#    'district': 'Brisbane City',
#    'city': 'Brisbane',
#    'lon': 153.026164,
#    'lat': -27.469309,
#    'state_code': 'QLD',
#    'formatted': 'Brisbane, Australia',
#    'address_line1': 'Brisbane',
#    'address_line2': 'Australia',
#    'timezone': {'name': 'Australia/Brisbane',
#     'offset_STD': '+10:00',
#     'offset_STD_seconds': 36000,
#     'offset_DST': '+10:00',
#     'offset_DST_seconds': 36000,
#     'abbreviation_STD': 'AEST',
#     'abbreviation_DST': 'AEST'},
#    'result_type': 'city',
#    'rank': {'popularity': 6.876406158741578,
#     'confidence': 0.5,
#     'confidence_city_level': 0.5,
#     'match_type': 'full_match'},
#    'place_id': '51a48ae255d620634059edb776a224783bc0c00208e2031e77686f736f6e66697273743a6c6f63616c6974793a313031393334303139',
#    'bbox': {'lon1': 153.010472,
#     'lat1': -27.479519,
#     'lon2': 153.03461,
#     'lat2': -27.459927}},
#   {'country_code': 'au',
#    'country': 'Australia',
#    'county': 'Brisbane',
#    'datasource': {'sourcename': 'whosonfirst',
#     'url': 'https://www.whosonfirst.org/docs/licenses/'},
#    'state': 'Queensland',
#    'district': 'South Brisbane',
#    'city': 'South Brisbane',
#    'lon': 153.018217,
#    'lat': -27.478959,
#    'state_code': 'QLD',
#    'formatted': 'South Brisbane, Brisbane, Australia',
#    'address_line1': 'South Brisbane',
#    'address_line2': 'Brisbane, Australia',
#    'timezone': {'name': 'Australia/Brisbane',
#     'offset_STD': '+10:00',
#     'offset_STD_seconds': 36000,
#     'offset_DST': '+10:00',
#     'offset_DST_seconds': 36000,
#     'abbreviation_STD': 'AEST',
#     'abbreviation_DST': 'AEST'},
#    'result_type': 'city',
#    'rank': {'popularity': 6.180111166273198,
#     'confidence': 0.5,
#     'confidence_city_level': 0.5,
#     'match_type': 'full_match'},
#    'place_id': '516667d13b9520634059f71f990e9d7a3bc0c00208e2031e77686f736f6e66697273743a6c6f63616c6974793a313031393335333231',
#    'bbox': {'lon1': 153.007996096,
#     'lat1': -27.490018694,
#     'lon2': 153.03189968,
#     'lat2': -27.4694628075}},
#   {'country_code': 'au',
#    'country': 'Australia',
#    'county': 'Brisbane',
#    'datasource': {'sourcename': 'geonames',
#     'license': 'CC BY 4.0',
#     'url': 'https://www.geonames.org/datasources/'},
#    'state': 'Queensland',
#    'city': 'East Brisbane',
#    'lon': 153.04401,
#    'lat': -27.48099,
#    'state_code': 'QLD',
#    'formatted': 'East Brisbane, QLD, Australia',
#    'address_line1': 'East Brisbane',
#    'address_line2': 'QLD, Australia',
#    'timezone': {'name': 'Australia/Brisbane',
#     'offset_STD': '+10:00',
#     'offset_STD_seconds': 36000,
#     'offset_DST': '+10:00',
#     'offset_DST_seconds': 36000,
#     'abbreviation_STD': 'AEST',
#     'abbreviation_DST': 'AEST'},
#    'result_type': 'suburb',
#    'rank': {'popularity': 5.195143172006435,
#     'confidence': 0,
#     'match_type': 'full_match'},
#    'place_id': '514dd6a8876821634059fab31f29227b3bc0c00205e2031e67656f6e616d65733a6e65696768626f7572686f6f643a32323037323538'}],
#  'query': {'text': 'Brisbane, Austrailia'}}

# %%
# Extract lat/lon
lat = geo_data['results'][0]['lat']
lon = geo_data['results'][0]['lon']
print('Lat = ' + str(lat))
print('Lon = ' + str(lon))
# Print results
# Out:
# Lat = 37.690193
# Lon = -122.340013

# %% [markdown]
# ## 2. Find the name and address of a pharmacy in Brisbane, Australia.
#
# > **Hint:** Review <https://apidocs.geoapify.com/docs/places/#categories>.

# %%
# Set the geographical coordinates for Brisbane, Australia
latitude = -27.4705
longitude = 153.0260

# Set the parameters for the type of place
categories = "commercial.health_and_beauty.pharmacy"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# %%
# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
response = requests.get(base_url, params=params).json()

# %%
# Print the results
print(response['features'][0]['properties']['name'])
response['features'][0]['properties']['address_line2']
# Out:
# Priceline Pharmacy
# '120 Queen Street, Brisbane City QLD 4001, Australia'

# %% [markdown]
# ## 3. Find a pet shop within a 5km radius from the Sydney Opera House.

# %%
# Set the geographical coordinates for the Sydney Opera House
latitude = -33.8568
longitude = 151.2153

# Set the parameters for the type of place
categories = "pet.shop"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# %%
# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
pet_response = requests.get(base_url, params=params).json()
pet_response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Woollahra Municipal Council',
#     'postcode': '2028',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Double Bay',
#     'street': 'Kiaora Road',
#     'lon': 151.2444929,
#     'lat': -33.8774433,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, Kiaora Road, Double Bay NSW 2028, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': 'Kiaora Road, Double Bay NSW 2028, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'osm_id': 4925657661,
#       'osm_type': 'n'}},
#     'distance': 3541,
#     'place_id': '515533c6e2d2e7624059bb15e20f50f040c0f00103f9013d929725010000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.24449289999998, -33.87744329966832]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'North Sydney Council',
#     'postcode': '2065',
#     'district': 'Lower North Shore',
#     'neighbourhood': 'Crows Nest Junction',
#     'suburb': 'Crows Nest',
#     'street': 'Willoughby Road',
#     'housenumber': '160',
#     'lon': 151.200736,
#     'lat': -33.822833,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, 160 Willoughby Road, Crows Nest NSW 2065, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': '160 Willoughby Road, Crows Nest NSW 2065, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'brand': 'Petbarn',
#       'osm_id': 2625901404,
#       'website': 'https://www.petbarn.com.au/store-finder/crows-nest',
#       'operator': 'Petbarn',
#       'osm_type': 'n',
#       'addr:state': 'NSW',
#       'addr:street': 'Willoughby Road',
#       'addr:suburb': 'Crows Nest',
#       'addr:country': 'AU',
#       'addr:postcode': 2065,
#       'brand:wikidata': 'Q104746468',
#       'addr:housenumber': 160}},
#     'distance': 4001,
#     'place_id': '512864e76d6ce662405943cd7b9752e940c0f00103f9015c13849c000000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.200736, -33.82283299965868]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pet O',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2038',
#     'district': 'Inner West',
#     'suburb': 'Annandale',
#     'street': 'The Crescent',
#     'housenumber': '1A',
#     'lon': 151.1758722,
#     'lat': -33.8760765,
#     'state_code': 'NSW',
#     'formatted': 'Pet O, 1A The Crescent, Annandale NSW 2038, Australia',
#     'address_line1': 'Pet O',
#     'address_line2': '1A The Crescent, Annandale NSW 2038, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Pet O',
#       'shop': 'pet',
#       'osm_id': 7726482861,
#       'website': 'https://peto.com.au/',
#       'osm_type': 'n',
#       'addr:street': 'The Crescent',
#       'addr:housenumber': '1A'}},
#     'distance': 4229,
#     'place_id': '51d168bcbea0e56240592c6f554623f040c0f00103f901adc588cc01000000920305506574204f'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.1758722, -33.87607649966807]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Dogue',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Waverley Council',
#     'postcode': '2022',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Bondi Junction',
#     'street': 'Oxford Street',
#     'lon': 151.2436647,
#     'lat': -33.8905695,
#     'state_code': 'NSW',
#     'formatted': 'Dogue, Oxford Street, Bondi Junction NSW 2022, Australia',
#     'address_line1': 'Dogue',
#     'address_line2': 'Oxford Street, Bondi Junction NSW 2022, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Dogue',
#       'shop': 'pet',
#       'osm_id': 5902886018,
#       'osm_type': 'n'}},
#     'distance': 4574,
#     'place_id': '5112b6e919cce762405945f36d2efef140c0f00103f90182e4d65f01000000920305446f677565'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2436647, -33.890569499670654]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Aquapets Aquariums',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Waverley Council',
#     'postcode': '2022',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Bondi Junction',
#     'street': 'Ebley Street',
#     'lon': 151.2491021,
#     'lat': -33.8935295,
#     'state_code': 'NSW',
#     'formatted': 'Aquapets Aquariums, Ebley Street, Bondi Junction NSW 2022, Australia',
#     'address_line1': 'Aquapets Aquariums',
#     'address_line2': 'Ebley Street, Bondi Junction NSW 2022, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Aquapets Aquariums',
#       'shop': 'pet',
#       'osm_id': 5338208460,
#       'osm_type': 'n'}},
#     'distance': 5136,
#     'place_id': '51ad9bf7a4f8e7624059ab8cb52c5ff240c0f00103f901cc982e3e01000000920312417175617065747320417175617269756d73'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2491021, -33.89352949967118]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Waverley Council',
#     'postcode': '2022',
#     'district': 'Eastern Suburbs',
#     'suburb': 'Bondi Junction',
#     'street': 'Bronte Road',
#     'lon': 151.2498808,
#     'lat': -33.8946355,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, Bronte Road, Bondi Junction NSW 2022, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': 'Bronte Road, Bondi Junction NSW 2022, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'osm_id': 5903363364,
#       'osm_type': 'n'}},
#     'distance': 5277,
#     'place_id': '51bffc0406ffe7624059f176826a83f240c0f00103f901242dde5f010000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2498808, -33.89463549967139]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petbarn',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2015',
#     'suburb': 'Macdonaldtown',
#     'street': 'Harley Street Cycleway',
#     'lon': 151.19352901096946,
#     'lat': -33.903913,
#     'state_code': 'NSW',
#     'formatted': 'Petbarn, Harley Street Cycleway, Macdonaldtown NSW 2015, Australia',
#     'address_line1': 'Petbarn',
#     'address_line2': 'Harley Street Cycleway, Macdonaldtown NSW 2015, Australia',
#     'categories': ['building',
#      'building.commercial',
#      'commercial',
#      'commercial.pet',
#      'pet',
#      'pet.shop'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petbarn',
#       'shop': 'pet',
#       'brand': 'Petbarn',
#       'osm_id': 61972938,
#       'building': 'commercial',
#       'osm_type': 'w',
#       'brand:wikidata': 'Q104746468'}},
#     'distance': 5587,
#     'place_id': '5123705c5031e66240592b9968f5b3f340c0f00102f901caa1b103000000009203075065746261726e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.1935197644644, -33.9039294014677]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Puppy Parlour',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Waverley Council',
#     'postcode': '2024',
#     'district': 'Eastern Suburbs',
#     'neighbourhood': 'Charing Cross',
#     'suburb': 'Queens Park',
#     'street': 'Carrington Road',
#     'lon': 151.2533907,
#     'lat': -33.9005095,
#     'state_code': 'NSW',
#     'formatted': 'Puppy Parlour, Carrington Road, Queens Park NSW 2024, Australia',
#     'address_line1': 'Puppy Parlour',
#     'address_line2': 'Carrington Road, Queens Park NSW 2024, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Puppy Parlour',
#       'shop': 'pet',
#       'osm_id': 6004908494,
#       'osm_type': 'n'}},
#     'distance': 5994,
#     'place_id': '518a33d0c61be86240594a6a31e543f340c0f00103f901cea1eb650100000092030d5075707079205061726c6f7572'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2533907, -33.900509499672424]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pets Palace',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Inner West Council',
#     'postcode': '2042',
#     'district': 'Inner West',
#     'suburb': 'Newtown',
#     'street': 'King Street',
#     'housenumber': '714',
#     'lon': 151.1812276,
#     'lat': -33.9065661,
#     'state_code': 'NSW',
#     'formatted': 'Pets Palace, 714 King Street, Newtown NSW 2042, Australia',
#     'address_line1': 'Pets Palace',
#     'address_line2': '714 King Street, Newtown NSW 2042, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Pets Palace',
#       'shop': 'pet',
#       'osm_id': 3275282201,
#       'osm_type': 'n'}},
#     'distance': 6357,
#     'place_id': '513fe4d29dcce562405947e1a25b0af440c0f00103f90119d738c30000000092030b506574732050616c616365'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.18122760000003, -33.906566099673505]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pet Town',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'town': 'Chatswood',
#     'municipality': 'Willoughby City Council',
#     'postcode': '2067',
#     'district': 'Lower North Shore',
#     'street': 'Anderson Street',
#     'lon': 151.1841025,
#     'lat': -33.7973368,
#     'state_code': 'NSW',
#     'formatted': 'Pet Town, Anderson Street, Sydney NSW 2067, Australia',
#     'address_line1': 'Pet Town',
#     'address_line2': 'Anderson Street, Sydney NSW 2067, Australia',
#     'categories': ['commercial',
#      'commercial.pet',
#      'pet',
#      'pet.shop',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details.commercial', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Pet Town',
#       'shop': 'pet',
#       'level': 2,
#       'osm_id': 8401323691,
#       'osm_type': 'n',
#       'level:ref': 4,
#       'wheelchair': 'yes'}},
#     'distance': 7200,
#     'place_id': '519313ed2ae4e5624059c334db210fe640c0f00103f901ab06c2f40100000092030850657420546f776e'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.18410249999997, -33.797336799654225]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Guide Dogs NSW/ACT',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'town': 'Chatswood',
#     'municipality': 'Willoughby City Council',
#     'postcode': '2067',
#     'district': 'Lower North Shore',
#     'street': 'Thomas Street',
#     'housenumber': '2-4',
#     'lon': 151.18045937352298,
#     'lat': -33.798157700000004,
#     'state_code': 'NSW',
#     'formatted': 'Guide Dogs NSW/ACT, 2-4 Thomas Street, Sydney NSW 2067, Australia',
#     'address_line1': 'Guide Dogs NSW/ACT',
#     'address_line2': '2-4 Thomas Street, Sydney NSW 2067, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': ['details.commercial', 'details.contact', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Guide Dogs NSW/ACT',
#       'shop': 'pet',
#       'indoor': 'room',
#       'osm_id': 450716625,
#       'osm_type': 'w',
#       'addr:city': 'Chatswood',
#       'wheelchair': 'no',
#       'addr:street': 'Thomas Street',
#       'addr:country': 'AU',
#       'addr:postcode': 2067,
#       'contact:email': 'chatswood@guidedogs.com.au',
#       'contact:phone': '+61 2 9412 9300',
#       'addr:housenumber': '2-4',
#       'opening_hours:signed': 'no'}},
#     'distance': 7254,
#     'place_id': '5148afba50c6e5624059bd708cb929e640c0f00102f901d163dd1a00000000920312477569646520446f6773204e53572f414354'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.180458416575, -33.79814833981934]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Petsville / Birdsville',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2015',
#     'suburb': 'Alexandria',
#     'street': 'Botany Road',
#     'housenumber': '684',
#     'lon': 151.1963567,
#     'lat': -33.9212098,
#     'state_code': 'NSW',
#     'formatted': 'Petsville / Birdsville, 684 Botany Road, Alexandria NSW 2015, Australia',
#     'address_line1': 'Petsville / Birdsville',
#     'address_line2': '684 Botany Road, Alexandria NSW 2015, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Petsville / Birdsville',
#       'shop': 'pet',
#       'osm_id': 8784419349,
#       'osm_type': 'n',
#       'addr:state': 'NSW',
#       'addr:street': 'Botany Road',
#       'addr:suburb': 'Alexandria',
#       'addr:postcode': 2015,
#       'addr:housenumber': 684}},
#     'distance': 7356,
#     'place_id': '51369bd88d48e66240598d2ee533eaf540c0f00103f901159a970b020000009203165065747376696c6c65202f20426972647376696c6c65'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.19635669999997, -33.92120979967613]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Pet O',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'city': 'Sydney',
#     'town': 'Chatswood',
#     'municipality': 'Willoughby City Council',
#     'postcode': '2067',
#     'district': 'Lower North Shore',
#     'street': 'Victoria Avenue',
#     'lon': 151.1938364497479,
#     'lat': -33.79269585,
#     'state_code': 'NSW',
#     'formatted': 'Pet O, Victoria Avenue, Sydney NSW 2067, Australia',
#     'address_line1': 'Pet O',
#     'address_line2': 'Victoria Avenue, Sydney NSW 2067, Australia',
#     'categories': ['building',
#      'building.commercial',
#      'commercial',
#      'commercial.pet',
#      'pet',
#      'pet.shop',
#      'wheelchair',
#      'wheelchair.yes'],
#     'details': ['details.building', 'details.facilities'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Pet O',
#       'shop': 'pet',
#       'osm_id': 553375029,
#       'building': 'retail',
#       'osm_type': 'w',
#       'wheelchair': 'yes',
#       'building:levels': 1}},
#     'distance': 7365,
#     'place_id': '51af84c3bf33e662405975c6a53176e540c0f00102f90135d5fb2000000000920305506574204f'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.19381702601592, -33.79266949266904]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Zen Aqua Centre',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'county': 'Bayside Council',
#     'city': 'Sydney',
#     'municipality': 'Council of the City of Sydney',
#     'postcode': '2018',
#     'suburb': 'Rosebery',
#     'street': 'Gardeners Road',
#     'lon': 151.2050538,
#     'lat': -33.9227238,
#     'state_code': 'NSW',
#     'formatted': 'Zen Aqua Centre, Gardeners Road, Rosebery NSW 2018, Australia',
#     'address_line1': 'Zen Aqua Centre',
#     'address_line2': 'Gardeners Road, Rosebery NSW 2018, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Zen Aqua Centre',
#       'shop': 'pet',
#       'osm_id': 9567329026,
#       'osm_type': 'n'}},
#     'distance': 7373,
#     'place_id': '51759dfccc8fe6624059eb6c3fd01bf640c0f00103f90102db413a0200000092030f5a656e20417175612043656e747265'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.2050538, -33.92272379967638]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Peppy Puppy',
#     'country': 'Australia',
#     'country_code': 'au',
#     'state': 'New South Wales',
#     'county': 'Bayside Council',
#     'city': 'Sydney',
#     'postcode': '2020',
#     'suburb': 'Mascot',
#     'street': 'Gardeners Road',
#     'lon': 151.1855631,
#     'lat': -33.9201317,
#     'state_code': 'NSW',
#     'formatted': 'Peppy Puppy, Gardeners Road, Mascot NSW 2020, Australia',
#     'address_line1': 'Peppy Puppy',
#     'address_line2': 'Gardeners Road, Mascot NSW 2020, Australia',
#     'categories': ['commercial', 'commercial.pet', 'pet', 'pet.shop'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Peppy Puppy',
#       'shop': 'pet',
#       'osm_id': 7615756230,
#       'osm_type': 'n'}},
#     'distance': 7544,
#     'place_id': '5105bb0622f0e56240597e0f23e0c6f540c0f00103f901c637efc50100000092030b5065707079205075707079'},
#    'geometry': {'type': 'Point',
#     'coordinates': [151.1855631, -33.920131699675935]}}]}

# %%
# Print the results
print(pet_response['features'][0]['properties']['name'])
pet_response['features'][0]['properties']['address_line2']
# Out:
# Petbarn
# 'Kiaora Road, Double Bay NSW 2028, Australia'

# %% [markdown]
# ## 4. Find the nearest dentist to your house.
#
# > **Hint:** Use Geoapify Geocode to find your latitude and Geoapify Places to find the dentist.

# %%
# Set the search parameters
target_city = 'Erie, Colorado'

# Build URL using the geocode endpoint
target_url = f"https://api.geoapify.com/v1/geocode/search?text={target_city}&format=json&apiKey={geoapify_key}"
target_url
# Out:
# 'https://api.geoapify.com/v1/geocode/search?text=Erie, Colorado&format=json&apiKey=c242fab0818a46ff9dda30ba393bfea0'

# %%
# Run request
dentist_data = requests.get(target_url).json()

# Print the json (pretty printed)
dentist_data
# Out:
# {'results': [{'datasource': {'sourcename': 'openstreetmap',
#     'attribution': '© OpenStreetMap contributors',
#     'license': 'Open Database License',
#     'url': 'https://www.openstreetmap.org/copyright'},
#    'country': 'United States',
#    'country_code': 'us',
#    'state': 'Colorado',
#    'county': 'Weld County',
#    'city': 'Erie',
#    'postcode': '80516',
#    'lon': -105.049981,
#    'lat': 40.0502623,
#    'state_code': 'CO',
#    'distance': 0,
#    'formatted': 'Erie, CO 80516, United States of America',
#    'address_line1': 'Erie, CO 80516',
#    'address_line2': 'United States of America',
#    'category': 'administrative',
#    'timezone': {'name': 'America/Denver',
#     'offset_STD': '-07:00',
#     'offset_STD_seconds': -25200,
#     'offset_DST': '-06:00',
#     'offset_DST_seconds': -21600,
#     'abbreviation_STD': 'MST',
#     'abbreviation_DST': 'MDT'},
#    'result_type': 'postcode',
#    'rank': {'importance': 0.63552331445595,
#     'popularity': 2.687106173557082,
#     'confidence': 1,
#     'confidence_city_level': 1,
#     'match_type': 'full_match'},
#    'place_id': '51f81a82e332435ac059625cbbfe6e064440f00101f901b3b6010000000000c00207',
#    'bbox': {'lon1': -105.104906,
#     'lat1': 40.0002435,
#     'lon2': -104.9794704,
#     'lat2': 40.1013195}}],
#  'query': {'text': 'Erie, Colorado',
#   'parsed': {'city': 'erie', 'state': 'colorado', 'expected_type': 'city'}}}

# %%
# Set the geographical coordinates
latitude = 40.0502623
longitude = -105.049981

# Set the parameters for the type of place
categories = "healthcare.dentist"
radius = 8000

# Set the parameters for the type of search
filters = f"circle:{longitude},{latitude},{radius}"
bias = f"proximity:{longitude},{latitude}"
limit = 20

params = {
    "categories":categories,
    "limit":limit,
    "filter":filters,
    "bias":bias,
    "apiKey":geoapify_key    
}

# %%
# Set base URL
base_url = "https://api.geoapify.com/v2/places"

# run a request using our params dictionary
dentist_response = requests.get(base_url, params=params).json()
dentist_response
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'name': 'Patil Orthodontics',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Weld County',
#     'city': 'Erie',
#     'postcode': '80516',
#     'street': 'Mitchell Way',
#     'housenumber': '615',
#     'lon': -105.0513222,
#     'lat': 40.0365104,
#     'state_code': 'CO',
#     'formatted': 'Patil Orthodontics, 615 Mitchell Way, Erie, CO 80516, United States of America',
#     'address_line1': 'Patil Orthodontics',
#     'address_line2': '615 Mitchell Way, Erie, CO 80516, United States of America',
#     'categories': ['healthcare', 'healthcare.dentist'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Patil Orthodontics',
#       'osm_id': 5086474897,
#       'amenity': 'dentist',
#       'osm_type': 'n',
#       'addr:city': 'Erie',
#       'addr:state': 'CO',
#       'healthcare': 'dentist',
#       'addr:street': 'Mitchell Way',
#       'addr:postcode': 80516,
#       'addr:housenumber': 615}},
#     'distance': 1531,
#     'place_id': '51c3a3e8dc48435ac0590a916f5fac044440f00103f90191722d2f01000000920312506174696c204f7274686f646f6e74696373'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.0513222, 40.036510400272235]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Block Buster',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Boulder County',
#     'city': 'Erie',
#     'hamlet': 'Ninemile Corner',
#     'postcode': '80026',
#     'street': 'Billington Drive',
#     'lon': -105.10029665843422,
#     'lat': 40.01631545,
#     'state_code': 'CO',
#     'formatted': 'Block Buster, Billington Drive, Erie, CO 80026, United States of America',
#     'address_line1': 'Block Buster',
#     'address_line2': 'Billington Drive, Erie, CO 80026, United States of America',
#     'categories': ['building',
#      'building.healthcare',
#      'healthcare',
#      'healthcare.dentist'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Block Buster',
#       'osm_id': 35024139,
#       'amenity': 'dentist',
#       'building': 'yes',
#       'osm_type': 'w',
#       'healthcare': 'dentist'}},
#     'distance': 5702,
#     'place_id': '51f1af23486b465ac059dd9bbb9116024440f00102f9010b6d16020000000092030c426c6f636b20427573746572'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.1002979610928, 40.01631375942791]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Mountain Ridge Dental Care',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Weld County',
#     'city': 'Erie',
#     'postcode': '80516',
#     'street': 'East 168th Avenue',
#     'housenumber': '2297',
#     'lon': -105.01444794356574,
#     'lat': 40.00069055,
#     'state_code': 'CO',
#     'formatted': 'Mountain Ridge Dental Care, 2297 East 168th Avenue, Erie, CO 80516, United States of America',
#     'address_line1': 'Mountain Ridge Dental Care',
#     'address_line2': '2297 East 168th Avenue, Erie, CO 80516, United States of America',
#     'categories': ['building',
#      'building.healthcare',
#      'healthcare',
#      'healthcare.dentist'],
#     'details': ['details.contact'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Mountain Ridge Dental Care',
#       'phone': '(303) 604-6460',
#       'osm_id': 831267671,
#       'amenity': 'dentist',
#       'building': 'yes',
#       'osm_type': 'w',
#       'addr:city': 'Erie',
#       'addr:state': 'CO',
#       'healthcare': 'dentist',
#       'addr:street': 'CO-7',
#       'addr:postcode': 80516,
#       'addr:housenumber': 2297}},
#     'distance': 6271,
#     'place_id': '51bd105fb5ec405ac0599d3460d316004440f00102f90157238c310000000092031a4d6f756e7461696e2052696467652044656e74616c2043617265'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.01444753917436, 40.00069658467803]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Erie Modern Dentistry',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Weld County',
#     'city': 'Erie',
#     'postcode': '80516',
#     'street': 'East 168th Avenue',
#     'housenumber': '1927',
#     'lon': -105.01044008572087,
#     'lat': 40.0006869,
#     'state_code': 'CO',
#     'formatted': 'Erie Modern Dentistry, 1927 East 168th Avenue, Erie, CO 80516, United States of America',
#     'address_line1': 'Erie Modern Dentistry',
#     'address_line2': '1927 East 168th Avenue, Erie, CO 80516, United States of America',
#     'categories': ['building',
#      'building.healthcare',
#      'healthcare',
#      'healthcare.dentist'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Erie Modern Dentistry',
#       'osm_id': 828868745,
#       'amenity': 'dentist',
#       'building': 'yes',
#       'osm_type': 'w',
#       'addr:city': 'Erie',
#       'addr:unit': 101,
#       'addr:state': 'CO',
#       'healthcare': 'dentist',
#       'addr:street': 'CO-7',
#       'addr:postcode': 80516,
#       'addr:housenumber': 1927}},
#     'distance': 6442,
#     'place_id': '513d0f9407ab405ac059080962a616004440f00102f901898867310000000092031545726965204d6f6465726e2044656e746973747279'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.01043881853998, 40.00069122111205]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Lafayette Dentistry',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Boulder County',
#     'city': 'Lafayette',
#     'postcode': '80026',
#     'street': 'Crossing Drive',
#     'housenumber': '511',
#     'lon': -105.1021882,
#     'lat': 40.0026547,
#     'state_code': 'CO',
#     'formatted': 'Lafayette Dentistry, 511 Crossing Drive, Lafayette, CO 80026, United States of America',
#     'address_line1': 'Lafayette Dentistry',
#     'address_line2': '511 Crossing Drive, Lafayette, CO 80026, United States of America',
#     'categories': ['healthcare', 'healthcare.dentist'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Lafayette Dentistry',
#       'osm_id': 1455003801,
#       'amenity': 'dentist',
#       'osm_type': 'n',
#       'healthcare': 'dentist'}},
#     'distance': 6914,
#     'place_id': '515f4260408a465ac059486a3dfd56004440f00103f9019998b956000000009203134c61666179657474652044656e746973747279'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.10218819999999, 40.00265470026767]}},
#   {'type': 'Feature',
#    'properties': {'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Boulder County',
#     'city': 'Lafayette',
#     'postcode': '80026',
#     'street': 'Diamond Circle',
#     'lon': -105.10486035,
#     'lat': 40.0041472,
#     'state_code': 'CO',
#     'formatted': 'Diamond Circle, Lafayette, CO 80026, United States of America',
#     'address_line1': 'Diamond Circle',
#     'address_line2': 'Lafayette, CO 80026, United States of America',
#     'categories': ['building',
#      'building.healthcare',
#      'healthcare',
#      'healthcare.dentist'],
#     'details': [],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'osm_id': 728252144,
#       'amenity': 'dentist',
#       'building': 'yes',
#       'osm_type': 'w',
#       'healthcare': 'dentist'}},
#     'distance': 6923,
#     'place_id': '516a792f08b6465ac0599ec23ce587004440f00102f901f03e682b00000000'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.10486035, 40.004147200267866]}},
#   {'type': 'Feature',
#    'properties': {'name': 'The Dental Shoppe',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Boulder County',
#     'city': 'Lafayette',
#     'postcode': '80026',
#     'street': 'West Baseline Road',
#     'lon': -105.1036773,
#     'lat': 39.9996439,
#     'state_code': 'CO',
#     'formatted': 'The Dental Shoppe, West Baseline Road, Lafayette, CO 80026, United States of America',
#     'address_line1': 'The Dental Shoppe',
#     'address_line2': 'West Baseline Road, Lafayette, CO 80026, United States of America',
#     'categories': ['healthcare', 'healthcare.dentist'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'The Dental Shoppe',
#       'osm_id': 1176375543,
#       'amenity': 'dentist',
#       'website': 'https://www.dentalshoppe.com/',
#       'osm_type': 'n',
#       'addr:unit': 104,
#       'healthcare': 'dentist'}},
#     'distance': 7253,
#     'place_id': '519b351da6a2465ac0599aa5d154f4ff4340f00103f901f7101e46000000009203115468652044656e74616c2053686f707065'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.1036773, 39.99964390026726]}},
#   {'type': 'Feature',
#    'properties': {'name': 'Comfort Dental',
#     'country': 'United States',
#     'country_code': 'us',
#     'state': 'Colorado',
#     'county': 'Boulder County',
#     'city': 'Lafayette',
#     'postcode': '80026',
#     'street': 'West South Boulder Road',
#     'housenumber': '535',
#     'lon': -105.095489,
#     'lat': 39.9878511,
#     'state_code': 'CO',
#     'formatted': 'Comfort Dental, 535 West South Boulder Road, Lafayette, CO 80026, United States of America',
#     'address_line1': 'Comfort Dental',
#     'address_line2': '535 West South Boulder Road, Lafayette, CO 80026, United States of America',
#     'categories': ['healthcare', 'healthcare.dentist'],
#     'details': ['details'],
#     'datasource': {'sourcename': 'openstreetmap',
#      'attribution': '© OpenStreetMap contributors',
#      'license': 'Open Database Licence',
#      'url': 'https://www.openstreetmap.org/copyright',
#      'raw': {'name': 'Comfort Dental',
#       'brand': 'Comfort Dental',
#       'osm_id': 1638476820,
#       'amenity': 'dentist',
#       'osm_type': 'n',
#       'healthcare': 'dentist',
#       'brand:wikidata': 'Q22079521',
#       'brand:wikipedia': 'en:Comfort Dental'}},
#     'distance': 7945,
#     'place_id': '512c08e57d1c465ac059b37aa4e771fe4340f00103f901142ca9610000000092030e436f6d666f72742044656e74616c'},
#    'geometry': {'type': 'Point',
#     'coordinates': [-105.09548899999999, 39.98785110026565]}}]}

# %%
# Print the results
print(dentist_response['features'][0]['properties']['name'])
dentist_response['features'][0]['properties']['address_line2']
# Out:
# Patil Orthodontics
# '615 Mitchell Way, Erie, CO 80516, United States of America'
